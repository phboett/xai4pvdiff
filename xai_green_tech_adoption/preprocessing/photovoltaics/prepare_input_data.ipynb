# %%
import os
import pandas as pd

os.chdir("../../..")
from xai_green_tech_adoption.utils.utils import *

pd.options.mode.chained_assignment = None

# %%
# choose target feature
max_capacity = 10

t_start_target = 0
t_end_target = 2021
target_col = col_power_accum_pv
denominator_column = col_count_households

# %% [markdown]
# ## 1. Prepare descriptive features

# %% [markdown]
# ### 1.1. Load INKAR dataset and delete irrelevant columns

# %%
df_inkar = pd.read_csv("data/intermediate_data/preprocessed_inkar_data.csv", sep=";")
df_inkar.head()
# Out:
#   Name of municipality ass.  Code of municipality associations (RS)  \
# 0          Flensburg, Stadt                                10010000
# 1    Kiel, Landeshauptstadt                                10020000
# 2        Lübeck, Hansestadt                                10030000
# 3         Neumünster, Stadt                                10040000
# 4        Brunsbüttel, Stadt                                10510011
#
#    County code  State code  Arbeitslose  \
# 0         1001           1       4174.0
# 1         1002           1      10556.0
# 2         1003           1       8400.0
# 3         1004           1       3386.0
# 4         1051           1        335.0
#
#    sozialversicherungspflichtig Beschäftigte am Arbeitsort  \
# 0                                            44607.0
# 1                                           125483.0
# 2                                            99053.0
# 3                                            40641.0
# 4                                             7025.0
#
#    sozialversicherungspflichtig Beschäftigte am Wohnort  Bevölkerung gesamt  \
# 0                                            32323.0                90164.0
# 1                                            91908.0               246794.0
# 2                                            80035.0               216530.0
# 3                                            30015.0                80196.0
# 4                                             4711.0                12380.0
#
#    Bevölkerung männlich  Bevölkerung weiblich  ...  Umsatz Bauhauptgewerbe  \
# 0               44904.0               45260.0  ...                  120.63
# 1              120198.0              126596.0  ...                  111.89
# 2              104032.0              112498.0  ...                  138.15
# 3               39723.0               40473.0  ...                  112.16
# 4                6240.0                6140.0  ...                  123.86
#
#    Anteil Bruttowertschöpfung Primärer Sektor  \
# 0                                        0.01
# 1                                        0.02
# 2                                        0.11
# 3                                        0.28
# 4                                        4.05
#
#    Anteil Bruttowertschöpfung Sekundärer Sektor  \
# 0                                         21.13
# 1                                         16.81
# 2                                         23.01
# 3                                         24.10
# 4                                         37.91
#
#    Anteil Bruttowertschöpfung Tertiärer Sektor  Beschäftigte im Handwerk  \
# 0                                        78.86                     11.61
# 1                                        83.17                      7.99
# 2                                        76.89                     15.44
# 3                                        75.62                     10.73
# 4                                        58.04                     15.95
#
#    Kleinstbetriebe  Kleinbetriebe  Mittlere Unternehmen  Großunternehmen  \
# 0            82.77          13.34                  3.28             0.60
# 1            83.30          12.79                  3.16             0.75
# 2            85.35          11.14                  2.92             0.59
# 3            82.80          13.30                  3.36             0.54
# 4            88.09          10.10                  1.65             0.16
#
#    Umsatz im Handwerk
# 0              116.25
# 1               88.41
# 2               81.05
# 3              128.06
# 4              106.46
#
# [5 rows x 186 columns]

# %%
df_inkar.drop([col_id_s, col_id_c], inplace=True, axis=1)
df_inkar.head()
# Out:
#   Name of municipality ass.  Code of municipality associations (RS)  \
# 0          Flensburg, Stadt                                10010000
# 1    Kiel, Landeshauptstadt                                10020000
# 2        Lübeck, Hansestadt                                10030000
# 3         Neumünster, Stadt                                10040000
# 4        Brunsbüttel, Stadt                                10510011
#
#    Arbeitslose  sozialversicherungspflichtig Beschäftigte am Arbeitsort  \
# 0       4174.0                                            44607.0
# 1      10556.0                                           125483.0
# 2       8400.0                                            99053.0
# 3       3386.0                                            40641.0
# 4        335.0                                             7025.0
#
#    sozialversicherungspflichtig Beschäftigte am Wohnort  Bevölkerung gesamt  \
# 0                                            32323.0                90164.0
# 1                                            91908.0               246794.0
# 2                                            80035.0               216530.0
# 3                                            30015.0                80196.0
# 4                                             4711.0                12380.0
#
#    Bevölkerung männlich  Bevölkerung weiblich  \
# 0               44904.0               45260.0
# 1              120198.0              126596.0
# 2              104032.0              112498.0
# 3               39723.0               40473.0
# 4                6240.0                6140.0
#
#    Erwerbsfähige Bevölkerung (15 bis unter 65 Jahre)  \
# 0                                            60031.0
# 1                                           169760.0
# 2                                           138758.0
# 3                                            51220.0
# 4                                             7593.0
#
#    Bevölkerung (mit Korrektur VZ 1987/Zensus 2011)  ...  \
# 0                                          90164.0  ...
# 1                                         246794.0  ...
# 2                                         216530.0  ...
# 3                                          80196.0  ...
# 4                                          12380.0  ...
#
#    Umsatz Bauhauptgewerbe  Anteil Bruttowertschöpfung Primärer Sektor  \
# 0                  120.63                                        0.01
# 1                  111.89                                        0.02
# 2                  138.15                                        0.11
# 3                  112.16                                        0.28
# 4                  123.86                                        4.05
#
#    Anteil Bruttowertschöpfung Sekundärer Sektor  \
# 0                                         21.13
# 1                                         16.81
# 2                                         23.01
# 3                                         24.10
# 4                                         37.91
#
#    Anteil Bruttowertschöpfung Tertiärer Sektor  Beschäftigte im Handwerk  \
# 0                                        78.86                     11.61
# 1                                        83.17                      7.99
# 2                                        76.89                     15.44
# 3                                        75.62                     10.73
# 4                                        58.04                     15.95
#
#    Kleinstbetriebe  Kleinbetriebe  Mittlere Unternehmen  Großunternehmen  \
# 0            82.77          13.34                  3.28             0.60
# 1            83.30          12.79                  3.16             0.75
# 2            85.35          11.14                  2.92             0.59
# 3            82.80          13.30                  3.36             0.54
# 4            88.09          10.10                  1.65             0.16
#
#    Umsatz im Handwerk
# 0              116.25
# 1               88.41
# 2               81.05
# 3              128.06
# 4              106.46
#
# [5 rows x 184 columns]

# %%
# translate German variable names from INKAR dataset to English
df_inkar_translation = pd.read_csv(
    "data/intermediate_data/variable_names_INKAR_engl_german.csv",
    sep=";",
    usecols=["German name in original Inkar data set", "English name"],
)
translation = {
    df_inkar_translation["German name in original Inkar data set"][
        variable
    ]: df_inkar_translation["English name"][variable]
    for variable in df_inkar_translation.index
}
df_inkar_engl = df_inkar.rename(translation, axis=1)

# %% [markdown]
# ### 1.2. Load and add election results published by Regional Database (Regionalstatistik) and ownership-occupation ratio and household sizes published by Census 2011
#
# Firstly, add election results from 2017 published by Regional Database.

# %%
df_election = pd.read_csv(
    "data/intermediate_data/preprocessed_election_data.csv", 
    sep=";", 
    usecols=[
        col_id_ma,
        col_vote_count_afd,
        col_vote_count_cdu,
        col_vote_count_fdp,
        col_vote_count_green,
        col_vote_count_left,
        col_vote_count_spd,
        col_vote_count_other,
    ]
)

df_descriptive = df_inkar_engl.merge(df_election, on=col_id_ma, how="left")
display(df_descriptive[df_descriptive[col_id_ma].isna()])
# Out:
# Empty DataFrame
# Columns: [Name of municipality ass., Code of municipality associations (RS), unemployed, employees at place of work, employees at place of residence, population, male population, female population, population of working age, population (Census 2011), floor space, completed flats, planning permissions for flats, completed flats (per capita), completed (semi-) detached houses (per capita), completed flats in multiple dwelling units (per capita), (semi-) detached houses, multiple dwelling units, studio and two-room apartments, flats with 5+ rooms, flats in (semi-) detached houses, flats in multiple dwelling units, employment rate, employment rate of women, employment rate of men, proportion young/elderly, population under 6 years, population (6-17 years), population (18-24 years), population (25-29 years), population (30-49 years), population (50-64 years), population (65+ years), population (75+ years), female population (75+ years), female population (18-24 years), female population (25-29 years), female population (65+ years), population (65-74 years), female population (65-74 years), population under 3 years, population (3-6 years), mean age, rate of young dependants, rate of elderly dependants, percentage of women, percentage of women (20-39 years), net migration, births, deaths, balance of biths and deaths, settlement and traffic area, habitat density, recreational area, per capita recreational area, open area, per capita open area, agricultural land, semi-natural area, per capita semi-natural area, forest area, water expanse, fiscal capacity, income tax, trade tax, value-added tax, population density, density of residents and employees, regional potential of population, in-commuter, out-commuter, net in-commuter, commuter travelling 50km+, commuter travelling 150km+, commuter travelling 300km+, accessibility of highways, accessibility of airports, accessibility of intercity train station, accessibility of regional centre, accessibility of middle-order centre, mean distance supermarket, distance supermarket max 1km, mean distance pharmacy, distance pharmacy max 1km, mean distance primary school, distance primary school max 1km, mean distance public transport, distance public transport max 1km, per capita permissions for (semi-) detached houses , per capita permissions for flats (multiple dwelling units), unemployment rate, unemployment rate of women, unemployment rate of men, price of building ground, completed buildings with renewable heat energy systems, completed flats with renewable heat energy systems, per capita residential floor area, labour force participation rate, self-employment rate, employees without any professional qualification, ...]
# Index: []
#
# [0 rows x 191 columns]

# %% [markdown]
# Second, add data on the owner occupation and the household sizes published by the Census 2011.

# %%
df_owner_occ = pd.read_csv(
    "data/intermediate_data/preprocessed_ownership_ratio.csv", sep=";"
)
df_hh_size = pd.read_csv(
    "data/intermediate_data/preprocessed_household_sizes_with_hh_counts.csv", sep=";"
)
df_descriptive = df_descriptive.merge(df_owner_occ, on=col_id_ma, how="left")
df_descriptive = df_descriptive.merge(df_hh_size, on=col_id_ma, how="left")
# check if data is available for all municipal associations
display(
    df_descriptive[df_descriptive[[owner_occ_ratio] + col_hh_sizes].isna().any(axis=1)]
)
# Out:
# Empty DataFrame
# Columns: [Name of municipality ass._x, Code of municipality associations (RS), unemployed, employees at place of work, employees at place of residence, population, male population, female population, population of working age, population (Census 2011), floor space, completed flats, planning permissions for flats, completed flats (per capita), completed (semi-) detached houses (per capita), completed flats in multiple dwelling units (per capita), (semi-) detached houses, multiple dwelling units, studio and two-room apartments, flats with 5+ rooms, flats in (semi-) detached houses, flats in multiple dwelling units, employment rate, employment rate of women, employment rate of men, proportion young/elderly, population under 6 years, population (6-17 years), population (18-24 years), population (25-29 years), population (30-49 years), population (50-64 years), population (65+ years), population (75+ years), female population (75+ years), female population (18-24 years), female population (25-29 years), female population (65+ years), population (65-74 years), female population (65-74 years), population under 3 years, population (3-6 years), mean age, rate of young dependants, rate of elderly dependants, percentage of women, percentage of women (20-39 years), net migration, births, deaths, balance of biths and deaths, settlement and traffic area, habitat density, recreational area, per capita recreational area, open area, per capita open area, agricultural land, semi-natural area, per capita semi-natural area, forest area, water expanse, fiscal capacity, income tax, trade tax, value-added tax, population density, density of residents and employees, regional potential of population, in-commuter, out-commuter, net in-commuter, commuter travelling 50km+, commuter travelling 150km+, commuter travelling 300km+, accessibility of highways, accessibility of airports, accessibility of intercity train station, accessibility of regional centre, accessibility of middle-order centre, mean distance supermarket, distance supermarket max 1km, mean distance pharmacy, distance pharmacy max 1km, mean distance primary school, distance primary school max 1km, mean distance public transport, distance public transport max 1km, per capita permissions for (semi-) detached houses , per capita permissions for flats (multiple dwelling units), unemployment rate, unemployment rate of women, unemployment rate of men, price of building ground, completed buildings with renewable heat energy systems, completed flats with renewable heat energy systems, per capita residential floor area, labour force participation rate, self-employment rate, employees without any professional qualification, ...]
# Index: []
#
# [0 rows x 201 columns]

# %% [markdown]
# ### 1.3. Load and add radiation data

# %%
df_radiation = pd.read_csv(
    "data/intermediate_data/ma_global_radiation.csv",
    sep=";",
    usecols=[col_id_ma, col_radiation],
)
df_descriptive = df_descriptive.merge(df_radiation, on=col_id_ma, how="left")
# check if data is available for all municipal associations
display(df_descriptive[df_descriptive[col_radiation].isna()])
# Out:
# Empty DataFrame
# Columns: [Name of municipality ass._x, Code of municipality associations (RS), unemployed, employees at place of work, employees at place of residence, population, male population, female population, population of working age, population (Census 2011), floor space, completed flats, planning permissions for flats, completed flats (per capita), completed (semi-) detached houses (per capita), completed flats in multiple dwelling units (per capita), (semi-) detached houses, multiple dwelling units, studio and two-room apartments, flats with 5+ rooms, flats in (semi-) detached houses, flats in multiple dwelling units, employment rate, employment rate of women, employment rate of men, proportion young/elderly, population under 6 years, population (6-17 years), population (18-24 years), population (25-29 years), population (30-49 years), population (50-64 years), population (65+ years), population (75+ years), female population (75+ years), female population (18-24 years), female population (25-29 years), female population (65+ years), population (65-74 years), female population (65-74 years), population under 3 years, population (3-6 years), mean age, rate of young dependants, rate of elderly dependants, percentage of women, percentage of women (20-39 years), net migration, births, deaths, balance of biths and deaths, settlement and traffic area, habitat density, recreational area, per capita recreational area, open area, per capita open area, agricultural land, semi-natural area, per capita semi-natural area, forest area, water expanse, fiscal capacity, income tax, trade tax, value-added tax, population density, density of residents and employees, regional potential of population, in-commuter, out-commuter, net in-commuter, commuter travelling 50km+, commuter travelling 150km+, commuter travelling 300km+, accessibility of highways, accessibility of airports, accessibility of intercity train station, accessibility of regional centre, accessibility of middle-order centre, mean distance supermarket, distance supermarket max 1km, mean distance pharmacy, distance pharmacy max 1km, mean distance primary school, distance primary school max 1km, mean distance public transport, distance public transport max 1km, per capita permissions for (semi-) detached houses , per capita permissions for flats (multiple dwelling units), unemployment rate, unemployment rate of women, unemployment rate of men, price of building ground, completed buildings with renewable heat energy systems, completed flats with renewable heat energy systems, per capita residential floor area, labour force participation rate, self-employment rate, employees without any professional qualification, ...]
# Index: []
#
# [0 rows x 202 columns]

# %% [markdown]
# ## 2. Prepare and add target feature

# %%
df_incl_target = df_descriptive.merge(
    pd.read_csv(
        f"data/intermediate_data/pv_ma_{t_start_target}_{t_end_target}_max_{max_capacity}.csv",
        sep=";",
        usecols=[col_id_ma, target_col],
    ),
    on=col_id_ma,
    how="left",
)
df_incl_target[target_col] = (
    df_incl_target[target_col] / df_incl_target[denominator_column]
)

# check if PV systems are installed in all municipal associations
display(df_incl_target[df_incl_target[target_col].isna()])
# col_count_pv_accum is NaN -> no pv installations in ma -> change to zero
df_incl_target.loc[df_incl_target[target_col].isna(), target_col] = 0

# save input data
df_incl_target.to_csv(f"data/input/input.csv", sep=";", index=False)
# Out:
# Empty DataFrame
# Columns: [Name of municipality ass._x, Code of municipality associations (RS), unemployed, employees at place of work, employees at place of residence, population, male population, female population, population of working age, population (Census 2011), floor space, completed flats, planning permissions for flats, completed flats (per capita), completed (semi-) detached houses (per capita), completed flats in multiple dwelling units (per capita), (semi-) detached houses, multiple dwelling units, studio and two-room apartments, flats with 5+ rooms, flats in (semi-) detached houses, flats in multiple dwelling units, employment rate, employment rate of women, employment rate of men, proportion young/elderly, population under 6 years, population (6-17 years), population (18-24 years), population (25-29 years), population (30-49 years), population (50-64 years), population (65+ years), population (75+ years), female population (75+ years), female population (18-24 years), female population (25-29 years), female population (65+ years), population (65-74 years), female population (65-74 years), population under 3 years, population (3-6 years), mean age, rate of young dependants, rate of elderly dependants, percentage of women, percentage of women (20-39 years), net migration, births, deaths, balance of biths and deaths, settlement and traffic area, habitat density, recreational area, per capita recreational area, open area, per capita open area, agricultural land, semi-natural area, per capita semi-natural area, forest area, water expanse, fiscal capacity, income tax, trade tax, value-added tax, population density, density of residents and employees, regional potential of population, in-commuter, out-commuter, net in-commuter, commuter travelling 50km+, commuter travelling 150km+, commuter travelling 300km+, accessibility of highways, accessibility of airports, accessibility of intercity train station, accessibility of regional centre, accessibility of middle-order centre, mean distance supermarket, distance supermarket max 1km, mean distance pharmacy, distance pharmacy max 1km, mean distance primary school, distance primary school max 1km, mean distance public transport, distance public transport max 1km, per capita permissions for (semi-) detached houses , per capita permissions for flats (multiple dwelling units), unemployment rate, unemployment rate of women, unemployment rate of men, price of building ground, completed buildings with renewable heat energy systems, completed flats with renewable heat energy systems, per capita residential floor area, labour force participation rate, self-employment rate, employees without any professional qualification, ...]
# Index: []
#
# [0 rows x 203 columns]
